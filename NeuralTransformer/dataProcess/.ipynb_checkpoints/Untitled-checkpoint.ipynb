# %%
# 列出文件目录
session1= "/home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1"
label0 = [1, 2, 3, 0, 2, 0, 0, 1, 0, 1, 2, 1, 1, 1, 2, 3, 2, 2, 3, 3, 0, 3, 0, 3]

# %%
import os
# 列出文件目录里的文件
def get_sorted_files(directory):
    try:
        # 获取目录中的所有文件和文件夹
        files_and_dirs = os.listdir(directory)
        # 过滤出文件
        files = [f for f in files_and_dirs if os.path.isfile(os.path.join(directory, f))]
        # 按文件名排序
        # files = sorted(files, key=extract_number)
        return files
    except Exception as e:
        return str(e)

sorted_files = get_sorted_files(session1)
for filename in sorted_files:
    file_path = os.path.join(session1, filename)
    # 处理单个文件
    # train_set, train_label, test_set, test_label = process_file(file_path, label)
    print(file_path)
# Out:
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/13_20151115.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/15_20150508.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/9_20151028.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/4_20151111.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/2_20150915.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/11_20150916.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/6_20150507.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/7_20150715.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/5_20160406.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/3_20150919.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/8_20151103.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/1_20160518.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/10_20151014.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/14_20151205.mat
# /home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/12_20150725.mat

# %%
file_path = '/home/gxx/Documents/pythonProjects/datasets/SEED_IV/eeg_raw_data/1/13_20151115.mat'
train_set, train_label, test_set, test_label = process_file(file_path, label)
